# %%
tab=read.table('genomic_windows_WithOutgroups_concord.cf.stat',header=TRUE, sep = "\t")

# %%
tab
# Out:
#    ID gCF   gCF_N gDF1  gDF1_N gDF2  gDF2_N gDFP  gDFP_N gN
# 1  47    NA    NA    NA   NA      NA   NA      NA    NA     NA
# 2  48 14.52  3755  5.54 1432    4.61 1192   75.33 19480  25859
# 3  49 50.44 13043  4.20 1085    5.00 1292   40.37 10439  25859
# 4  50  3.24   838  0.48  125    2.83  733   93.44 24163  25859
# 5  51  4.31  1115  0.28   73    1.35  348   94.06 24323  25859
# 6  52 10.51  2718  2.83  731    6.55 1695   80.11 20715  25859
# 7  53 22.73  5879  1.51  390    0.61  159   75.14 19431  25859
# 8  54 16.78  4339  4.71 1218    4.01 1038   74.50 19264  25859
# 9  55  4.57  1183  2.92  756    0.87  224   91.64 23696  25859
# 10 56  3.63   939  3.61  934    2.93  757   89.83 23229  25859
# 11 57 11.35  2935  8.13 2102    7.63 1974   72.89 18848  25859
# 12 58 12.68  3278  2.38  615    1.01  260   83.94 21706  25859
# 13 59 33.54  8673  9.70 2509    8.73 2258   48.03 12419  25859
# 14 60  1.36   352  0.18   47    0.33   85   98.13 25375  25859
# ...

# %%
hist(tab$gCF)
# Out:
# Plot with title “Histogram of tab$gCF”
